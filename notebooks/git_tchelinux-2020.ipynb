# %%
# Tchelinux Live 2020 - https://github.com/alexcamargoweb/tchelinux-2020
# Respositório da palestra "IA versus COVID-19: Deep Learning, Códigos e Execução em Nuvem".
# Notebook de configuração e execução do git via Colab/GitHub
# Arquivo: git_tchelinux-2020.ipynb

# %%
# CONFIGURAÇÕES INICIAIS DE SSH PARA REPOSITÓRIOS PRÓPRIOS DO GITHUB 
# Lembrando: esses comandos funcionarão no seu próprio repositório
# Importante: Executar um comando de cada vez

# Carrega os dados do Google Drive
from google.colab import drive, output
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/tchelinux-2020
# Limpa as saídas do terminal
output.clear()

# %cd /content/drive/MyDrive/

# !ssh-keygen -t rsa -b 4096 -C "alexcamargoweb@gmail.com"

# Adicione a saída do comando abaixo no seu perfil do GitHub
# !cat /root/.ssh/id_rsa.pub

# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !chmod 644 /root/.ssh/known_hosts
# !chmod 600 /root/.ssh/id_rsa

# !ssh -T git@github.com

# !git config --global user.email "alexcamargoweb@gmail.com"
# !git config --global user.name "alexcamargoweb"

# %cd /content/drive/MyDrive/
# %ls /content/drive/MyDrive/

# !git clone https://github.com/alexcamargoweb/tchelinux-2020.git

# %cd tchelinux-2020/
# %ls /content/drive/MyDrive/tchelinux-2020/
# Out:
# # github.com:22 SSH-2.0-babeld-b85a2946
# # github.com:22 SSH-2.0-babeld-b85a2946
# # github.com:22 SSH-2.0-babeld-b85a2946
# Warning: Permanently added the RSA host key for IP address '140.82.113.4' to the list of known hosts.
# Hi alexcamargoweb! You've successfully authenticated, but GitHub does not provide shell access.
# /content/drive/MyDrive
#  alex_novo.jpg  'Colab Notebooks'/   tchelinux-2020/           wrseg-2020/
#  Arquivos/       predict_covid/      trainingandtestdata.zip
# fatal: destination path 'tchelinux-2020' already exists and is not an empty directory.
# /content/drive/MyDrive/tchelinux-2020
# datasets/  inputs/  models/  notebooks/  plots/  README.md  slides/

# %%
# Carrega os dados do Google Drive
from google.colab import drive, output
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/tchelinux-2020
# Limpa as saídas do terminal
output.clear()

# %%
# Comandos git para manipulação do repositório local e via GitHub

# Configurações locais
# !git config --global user.email "alexcamargoweb@gmail.com"
# !git config --global user.name "alexcamargoweb"
# !rm /content/drive/MyDrive/tchelinux-2020/.git/index.lock

# exibe o status do repositório local
# !git status

# %ls -alh

# stash (se necessário), update, add, commit e push/pull as alterações
#!git stash
# !git add .
# !git commit -m 'notebooks e slides'
# !git push origin main
# Out:
# [main 5627780] notebooks e slides
#  113 files changed, 4 insertions(+), 1 deletion(-)
#  create mode 100644 .gitignore
#  create mode 100644 datasets/negativo/01.jpeg
#  create mode 100644 datasets/negativo/010.jpeg
#  create mode 100644 datasets/negativo/012.jpeg
#  create mode 100644 datasets/negativo/013.jpeg
#  create mode 100644 datasets/negativo/014.jpeg
#  create mode 100644 datasets/negativo/015.jpeg
#  create mode 100644 datasets/negativo/016.jpeg
#  create mode 100644 datasets/negativo/017.jpeg
#  create mode 100644 datasets/negativo/019.jpeg
#  create mode 100644 datasets/negativo/02.jpeg
#  create mode 100644 datasets/negativo/020.jpeg
#  create mode 100644 datasets/negativo/021.jpeg
#  create mode 100644 datasets/negativo/022.jpeg
#  create mode 100644 datasets/negativo/023.jpeg
#  create mode 100644 datasets/negativo/024.jpeg
#  create mode 100644 datasets/negativo/025.jpeg
#  create mode 100644 datasets/negativo/03.jpeg
#  create mode 100644 datasets/positivo/1-S2.0-S0929664620300449-GR2_LRG-D36.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300608-MAIN.PDF-00120.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300608-MAIN.PDF-0012039.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300608-MAIN.PDF-00138.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300608-MAIN.PDF-00221.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300608-MAIN.PDF-0022141.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300608-MAIN.PDF-00240.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-002-A122.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-002-A12243.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-002-A142.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-002-A223.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-002-A22345.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-002-A244.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-003-B124.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-003-B12447.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-003-B146.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-003-B225.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-003-B22549.png
#  create mode 100644 datasets/positivo/1-S2.0-S1684118220300682-MAIN.PDF-003-B248.png
#  create mode 100644 datasets/positivo/1-s2.0-S0140673620303706-fx1_lrg.png
#  create mode 100644 datasets/positivo/1-s2.0-S0929664620300449-gr2_lrg-a.png
#  create mode 100644 datasets/positivo/1-s2.0-S0929664620300449-gr2_lrg-b.png
#  create mode 100644 datasets/positivo/1-s2.0-S0929664620300449-gr2_lrg-c.png
#  create mode 100644 datasets/positivo/1-s2.0-S0929664620300449-gr2_lrg-d.png
#  create mode 100644 datasets/positivo/1-s2.0-S1684118220300608-main.pdf-001.png
#  create mode 100644 datasets/positivo/1-s2.0-S1684118220300608-main.pdf-002.png
#  create mode 100644 datasets/positivo/1-s2.0-S1684118220300682-main.pdf-002-a1.png
#  create mode 100644 datasets/positivo/1-s2.0-S1684118220300682-main.pdf-002-a2.png
#  create mode 100644 datasets/positivo/1-s2.0-S1684118220300682-main.pdf-003-b1.png
#  create mode 100644 datasets/positivo/1-s2.0-S1684118220300682-main.pdf-003-b2.png
#  delete mode 100644 git_tchelinux-2020.ipynb
#  create mode 100644 inputs/01.jpeg
#  create mode 100644 inputs/1.png
#  create mode 100644 models/.gitkeep
#  create mode 100644 models/model_tchelinux-2020.h5
#  create mode 100644 notebooks/git_tchelinux-2020.ipynb
#  create mode 100644 notebooks/predict_tchelinux-2020.ipynb
#  create mode 100644 notebooks/train_tchelinux-2020.ipynb
#  create mode 100644 plots/.gitkeep
#  create mode 100644 plots/results_tchelinux-2020.png
#  create mode 100644 slides/slides_tchelinux-2020.pdf
#  create mode 100644 slides/vgg16.png
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
